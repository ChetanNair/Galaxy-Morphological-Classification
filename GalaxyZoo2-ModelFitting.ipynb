# %%
import pickle

# Train and test pickles both contain the train and test data. 
# Data prep used to create the pickle files is presented in GalaxyZoo2-DataPrep.ipynb
with open('../input/pickles/train.pickle', 'rb') as f:
    X_train, y_train = pickle.load(f)

# %%
with open('../input/pickles/test.pickle', 'rb') as f:
    X_test, y_test = pickle.load(f)

# %%
# Verifying the shape of train data
print (X_train.shape, y_train.shape)
# Out:
# (49262, 64, 64, 3) (49262, 37)

# %%
# Defining the dimensions for image pre-processing
ORIG_SHAPE = (424,424)
CROP_SIZE = (256,256)
IMG_SHAPE = (64,64)



from keras.callbacks import TensorBoard
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense, BatchNormalization, GlobalMaxPooling2D
from keras import backend as K
import datetime

# Loss function
def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true))) 
    
# CNN Model
model = Sequential()
model.add(Conv2D(512, (3, 3), input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], 3)))
model.add(Conv2D(256, (3, 3)))
#model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3)))
model.add(Conv2D(128, (3, 3)))
#model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3)))
model.add(Conv2D(128, (3, 3)))
#model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(GlobalMaxPooling2D())


model.add(Dropout(0.25))
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Dense(37))
model.add(Activation('sigmoid'))
    


# Log for model training
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

model.compile(loss='binary_crossentropy', optimizer='adamax', metrics=[root_mean_squared_error])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 62, 512)       14336
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 60, 60, 256)       1179904
# _________________________________________________________________
# activation (Activation)      (None, 60, 60, 256)       0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 30, 30, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 256)       590080
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 26, 26, 128)       295040
# _________________________________________________________________
# activation_1 (Activation)    (None, 26, 26, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 128)       147584
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 9, 9, 128)         147584
# _________________________________________________________________
# activation_2 (Activation)    (None, 9, 9, 128)         0
# _________________________________________________________________
# global_max_pooling2d (Global (None, 128)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_4 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# activation_5 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 37)                4773
# _________________________________________________________________
# activation_6 (Activation)    (None, 37)                0
# =================================================================
# Total params: 2,428,837
# Trainable params: 2,428,837
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
#       <iframe id="tensorboard-frame-737eb90699ed27cb" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-737eb90699ed27cb");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
batch_size = 32
model.fit(X_train, y_train, epochs=30, validation_data=(X_test, y_test), batch_size=batch_size,callbacks=[tensorboard_callback])
# Out:
# Epoch 1/30
# 1540/1540 [==============================] - 93s 60ms/step - loss: 0.3110 - root_mean_squared_error: 0.1721 - val_loss: 0.2956 - val_root_mean_squared_error: 0.1591
# Epoch 2/30
# 1540/1540 [==============================] - 91s 59ms/step - loss: 0.2891 - root_mean_squared_error: 0.1529 - val_loss: 0.2694 - val_root_mean_squared_error: 0.1335
# Epoch 3/30
# 1540/1540 [==============================] - 91s 59ms/step - loss: 0.2686 - root_mean_squared_error: 0.1332 - val_loss: 0.2590 - val_root_mean_squared_error: 0.1226
# Epoch 4/30
# 1540/1540 [==============================] - 91s 59ms/step - loss: 0.2613 - root_mean_squared_error: 0.1251 - val_loss: 0.2537 - val_root_mean_squared_error: 0.1161
# Epoch 5/30
# 1540/1540 [==============================] - 91s 59ms/step - loss: 0.2572 - root_mean_squared_error: 0.1202 - val_loss: 0.2510 - val_root_mean_squared_error: 0.1124
# Epoch 6/30
# 1540/1540 [==============================] - 91s 59ms/step - loss: 0.2541 - root_mean_squared_error: 0.1163 - val_loss: 0.2497 - val_root_mean_squared_error: 0.1106
# Epoch 7/30
# 1540/1540 [==============================] - 91s 59ms/step - loss: 0.2519 - root_mean_squared_error: 0.1135 - val_loss: 0.2463 - val_root_mean_squared_error: 0.1064
# Epoch 8/30
# 1540/1540 [==============================] - 91s 59ms/step - loss: 0.2503 - root_mean_squared_error: 0.1113 - val_loss: 0.2481 - val_root_mean_squared_error: 0.1087
# Epoch 9/30
# 1540/1540 [==============================] - 92s 60ms/step - loss: 0.2491 - root_mean_squared_error: 0.1098 - val_loss: 0.2445 - val_root_mean_squared_error: 0.1036
# Epoch 10/30
# 1540/1540 [==============================] - 92s 60ms/step - loss: 0.2481 - root_mean_squared_error: 0.1084 - val_loss: 0.2445 - val_root_mean_squared_error: 0.1037
# Epoch 11/30
# 1540/1540 [==============================] - 92s 59ms/step - loss: 0.2473 - root_mean_squared_error: 0.1073 - val_loss: 0.2436 - val_root_mean_squared_error: 0.1023
# Epoch 12/30
# 1540/1540 [==============================] - 92s 60ms/step - loss: 0.2466 - root_mean_squared_error: 0.1063 - val_loss: 0.2429 - val_root_mean_squared_error: 0.1014
# Epoch 13/30
# 1540/1540 [==============================] - 92s 60ms/step - loss: 0.2459 - root_mean_squared_error: 0.1053 - val_loss: 0.2428 - val_root_mean_squared_error: 0.1013
# Epoch 14/30
# 1540/1540 [==============================] - 92s 59ms/step - loss: 0.2453 - root_mean_squared_error: 0.1045 - val_loss: 0.2422 - val_root_mean_squared_error: 0.1004
# Epoch 15/30
# 1540/1540 [==============================] - 91s 59ms/step - loss: 0.2449 - root_mean_squared_error: 0.1038 - val_loss: 0.2415 - val_root_mean_squared_error: 0.0990
# Epoch 16/30
# 1540/1540 [==============================] - 92s 59ms/step - loss: 0.2445 - root_mean_squared_error: 0.1032 - val_loss: 0.2407 - val_root_mean_squared_error: 0.0979
# Epoch 17/30
# 1540/1540 [==============================] - 92s 60ms/step - loss: 0.2439 - root_mean_squared_error: 0.1023 - val_loss: 0.2411 - val_root_mean_squared_error: 0.0984
# Epoch 18/30
# 1540/1540 [==============================] - 92s 60ms/step - loss: 0.2436 - root_mean_squared_error: 0.1019 - val_loss: 0.2405 - val_root_mean_squared_error: 0.0975
# Epoch 19/30
# 1540/1540 [==============================] - 92s 60ms/step - loss: 0.2431 - root_mean_squared_error: 0.1012 - val_loss: 0.2401 - val_root_mean_squared_error: 0.0969
# Epoch 20/30
# 1540/1540 [==============================] - 91s 59ms/step - loss: 0.2428 - root_mean_squared_error: 0.1008 - val_loss: 0.2404 - val_root_mean_squared_error: 0.0972
# Epoch 21/30
# 1540/1540 [==============================] - 92s 60ms/step - loss: 0.2424 - root_mean_squared_error: 0.1001 - val_loss: 0.2399 - val_root_mean_squared_error: 0.0965
# Epoch 22/30
# 1540/1540 [==============================] - 91s 59ms/step - loss: 0.2421 - root_mean_squared_error: 0.0997 - val_loss: 0.2397 - val_root_mean_squared_error: 0.0960
# Epoch 23/30
# 1540/1540 [==============================] - 92s 60ms/step - loss: 0.2416 - root_mean_squared_error: 0.0989 - val_loss: 0.2405 - val_root_mean_squared_error: 0.0973
# Epoch 24/30
# 1540/1540 [==============================] - 92s 59ms/step - loss: 0.2415 - root_mean_squared_error: 0.0986 - val_loss: 0.2401 - val_root_mean_squared_error: 0.0967
# Epoch 25/30
# 1540/1540 [==============================] - 92s 60ms/step - loss: 0.2412 - root_mean_squared_error: 0.0981 - val_loss: 0.2394 - val_root_mean_squared_error: 0.0957
# Epoch 26/30
# 1540/1540 [==============================] - 92s 59ms/step - loss: 0.2408 - root_mean_squared_error: 0.0975 - val_loss: 0.2395 - val_root_mean_squared_error: 0.0959
# Epoch 27/30
# 1540/1540 [==============================] - 92s 60ms/step - loss: 0.2406 - root_mean_squared_error: 0.0971 - val_loss: 0.2395 - val_root_mean_squared_error: 0.0958
# Epoch 28/30
# 1540/1540 [==============================] - 92s 59ms/step - loss: 0.2404 - root_mean_squared_error: 0.0968 - val_loss: 0.2389 - val_root_mean_squared_error: 0.0948
# Epoch 29/30
# 1540/1540 [==============================] - 92s 60ms/step - loss: 0.2401 - root_mean_squared_error: 0.0964 - val_loss: 0.2387 - val_root_mean_squared_error: 0.0943
# Epoch 30/30
# 1540/1540 [==============================] - 91s 59ms/step - loss: 0.2399 - root_mean_squared_error: 0.0960 - val_loss: 0.2390 - val_root_mean_squared_error: 0.0947

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 108), started 0:49:16 ago. (Use '!kill 108' to kill it.)
#       <iframe id="tensorboard-frame-f1010de360f250fe" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f1010de360f250fe");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
model.save('30epochsslow3).h5')

# %%
# !mkdir -p saved_model
model.save('saved_model/30epochsslow3')

# %%
model.save_weights('saved_weightsslow3')
